# %% [markdown]
# Final Session Requirements
# Format: Team project defense
#
# 1. General Description
# The final session represents a practical demonstration of your mastery of applying artificial intelligence techniques to solve a real problem. You must independently select a dataset, preprocess it, build an appropriate machine learning model, evaluate its performance, and improve results through parameter optimization or model adjustments (fine tuning).
# You are allowed to use Python, Jupyter Notebook, Google Colab, PyTorch, TensorFlow, scikit-learn, or any other approved AI toolkit.
#
# 2. Topic of the Final Session is free to choose
# Topic: Binary Classification of Fake vs. Real News Using Machine Learning Tools
# Dataset Example (Public):
#     • Fake and Real News Dataset (Kaggle)
# Link: https://www.kaggle.com/clmentbisaillon/fake-and-real-news-dataset
# You can use this dataset or choose any other dataset suitable for classification, regression, clustering, NLP or Computer Vision tasks.
#
# 3. Required Tasks
# Task 1. Dataset Acquisition and Description
#     1. Download the dataset from Kaggle or another open-source platform.
#     2. Provide a short description containing:
#         ◦ Dataset origin and link
#         ◦ Number of records
#         ◦ Number of features
#         ◦ Description of labels
#         ◦ Potential data quality issues (missing values, duplicates, imbalance)
#
# Task 2. Data Preprocessing
# Prepare the data for model training. Required steps:
#     1. Cleaning text or numeric features
#     2. Removing duplicates
#     3. Handling missing values
#     4. Splitting dataset into train/validation/test sets
#     5. Feature extraction (e.g., TF-IDF, embeddings, normalization)
#
# Task 3. Baseline Model Training
# Train a baseline machine learning/deep learning model.
#
# The team must:
#     1. Train the model on training data
#     2. Evaluate performance using all the metrics for their tasks. For instance, for classification task you must show Accuracy, Precision, Recall, F1-score. For regression task you must show MAE, MSE, RMSE, R2 – score.
# Provide a table of results.
#
# Task 4. Model Improvement (Mandatory)
# Improve the baseline model through any of the following techniques:
#     • Hyperparameter tuning
#     • Using a more complex model
#     • Changing feature extraction parameters
#     • Increasing data cleaning quality
#     • Data augmentation
# Even a 1% improvement in metrics is sufficient.
# The team must:
#     1. Describe what exactly was changed
#     2. Explain why this change improved the performance
#     3. Show the updated results
#     4. Compare performance before and after changes
#
# Task 5. Project defense
# Provide presentation of the defense:
#     1. Which model performed best and why
#     2. What limitations were identified
#     3. Which additional improvements could be applied in the future
#     4. How the chosen AI tools helped solve the task
#
# Task 6. Final Deliverables
# Each team must show:
# Source Code:
#     • Jupyter Notebook (.ipynb) or .py file or any other runnable type of files
#     • Must run without errors
#     • Must contain explanations, comments, and output cells
# Presentation for 12 slides max, showing each step in the project.

# %% [markdown]
# Формат требований к финальной сессии: Защита командного проекта
#
# Общее описание. Финальная сессия представляет собой практическую демонстрацию вашего мастерства применения методов искусственного интеллекта для решения реальной задачи. Вы должны самостоятельно выбрать набор данных, предварительно обработать его, построить подходящую модель машинного обучения, оценить ее производительность и улучшить результаты путем оптимизации параметров или корректировки модели (тонкой настройки). Вы можете использовать Python, Jupyter Notebook, Google Colab, PyTorch, TensorFlow, scikit-learn или любой другой утвержденный инструментарий ИИ.
#
# Тема финальной сессии на ваш выбор: Бинарная классификация фейковых и реальных новостей с использованием инструментов машинного обучения. Пример набора данных (общедоступный): • Набор данных «Фейковые и реальные новости» (Kaggle) Ссылка: https://www.kaggle.com/clmentbisaillon/fake-and-real-news-dataset Вы можете использовать этот набор данных или выбрать любой другой набор данных, подходящий для задач классификации, регрессии, кластеризации, обработки естественного языка или компьютерного зрения.
#
# Обязательные задачи
# Задача 1. Получение и описание набора данных
# Загрузите набор данных с Kaggle или другой платформы с открытым исходным кодом.
# Предоставьте краткое описание, содержащее: ◦ Происхождение и ссылка на набор данных ◦ Количество записей ◦ Количество признаков ◦ Описание меток ◦ Возможные проблемы с качеством данных (пропущенные значения, дубликаты, дисбаланс)
#
# Задача 2. Предварительная обработка данных Подготовьте данные для обучения модели. Обязательные шаги: 1. Очистка текстовых или числовых признаков 2. Удаление дубликатов 3. Обработка пропущенных значений 4. Разделение набора данных на обучающую/валидационную/тестовую выборки 5. Извлечение признаков (например, TF-IDF, эмбеддинги, нормализация)
#
# Задача 3. Обучение базовой модели Обучите базовую модель машинного обучения/глубокого обучения.
#
# Команда должна: 1. Обучить модель на обучающих данных 2. Оценить производительность, используя все метрики для своих задач. Например, для задачи классификации необходимо показать точность, прецизионность, полноту и F1-меру. Для задачи регрессии необходимо показать MAE, MSE, RMSE и R2-меру. Предоставьте таблицу результатов.
#
# Задание 4. Улучшение модели (обязательно). Улучшите базовую модель с помощью любого из следующих методов: • Настройка гиперпараметров • Использование более сложной модели • Изменение параметров извлечения признаков • Повышение качества очистки данных • Аугментация данных. Даже 1% улучшения метрик будет достаточно. Команда должна: 1. Описать, что именно было изменено; 2. Объяснить, почему это изменение улучшило производительность; 3. Показать обновленные результаты; 4. Сравнить производительность до и после изменений.
#
# Задание 5. Защита проекта. Представьте презентацию защиты: 1. Какая модель показала лучшие результаты и почему; 2. Какие ограничения были выявлены; 3. Какие дополнительные улучшения можно применить в будущем; 4. Как выбранные инструменты ИИ помогли решить задачу.
#
# Задание 6. Итоговые результаты. Каждая команда должна представить: Исходный код: • Jupyter Notebook (.ipynb) или файл .py или любой другой исполняемый файл • Должен работать без ошибок • Должен содержать пояснения, комментарии и ячейки с результатами. Презентация максимум из 12 слайдов, показывающая каждый шаг проекта.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import  re
from collections import Counter

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator

# %%
print('cuda ', torch.cuda.is_available())
print('gpu ', torch.cuda.get_device_name(0))
# Out:
# cuda  True
# gpu  NVIDIA GeForce GTX 1050

# %% [markdown]
# #### EDA

# %%
fake = pd.read_csv('data/Fake.csv/Fake.csv')
true = pd.read_csv('data/True.csv/True.csv')
fake.head(15)
# Out:
#                                                 title  \
# 0    Donald Trump Sends Out Embarrassing New Year’...
# 1    Drunk Bragging Trump Staffer Started Russian ...
# 2    Sheriff David Clarke Becomes An Internet Joke...
# 3    Trump Is So Obsessed He Even Has Obama’s Name...
# 4    Pope Francis Just Called Out Donald Trump Dur...
# 5    Racist Alabama Cops Brutalize Black Boy While...
# 6    Fresh Off The Golf Course, Trump Lashes Out A...
# 7    Trump Said Some INSANELY Racist Stuff Inside ...
# 8    Former CIA Director Slams Trump Over UN Bully...
# 9    WATCH: Brand-New Pro-Trump Ad Features So Muc...
# 10   Papa John’s Founder Retires, Figures Out Raci...
# 11   WATCH: Paul Ryan Just Told Us He Doesn’t Care...
# 12   Bad News For Trump — Mitch McConnell Says No ...
# 13   WATCH: Lindsey Graham Trashes Media For Portr...
# 14   Heiress To Disney Empire Knows GOP Scammed Us...
#
#                                                  text subject  \
# ...

# %%
true.head(15)
# Out:
#                                                 title  \
# 0   As U.S. budget fight looms, Republicans flip t...
# 1   U.S. military to accept transgender recruits o...
# 2   Senior U.S. Republican senator: 'Let Mr. Muell...
# 3   FBI Russia probe helped by Australian diplomat...
# 4   Trump wants Postal Service to charge 'much mor...
# 5   White House, Congress prepare for talks on spe...
# 6   Trump says Russia probe will be fair, but time...
# 7   Factbox: Trump on Twitter (Dec 29) - Approval ...
# 8          Trump on Twitter (Dec 28) - Global Warming
# 9   Alabama official to certify Senator-elect Jone...
# 10  Jones certified U.S. Senate winner despite Moo...
# 11  New York governor questions the constitutional...
# 12  Factbox: Trump on Twitter (Dec 28) - Vanity Fa...
# 13     Trump on Twitter (Dec 27) - Trump, Iraq, Syria
# 14  Man says he delivered manure to Mnuchin to pro...
#
#                                                  text       subject  \
# ...

# %%
# Labeling target
fake['label']=0
true['label']=1

# %%
df = pd.concat([fake, true], ignore_index=True)
df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
df['date'] = pd.to_datetime(df['date'], dayfirst=False, errors='coerce')

# %%
print('\033[44m         Basic statistics         \033[0m\n')

print(f'\033[34mShape\033[0m: {df.shape}\n')
print('\033[34mInfo\033[0m:')
print(df.info())
print('\n\033[34mDescriptive statistics\033[0m:\n',df.describe(include=object))
print('\n\033[34mNumber of news with the same subject\033[0m:\n',df.subject.value_counts())
print(f'\033[34m\nNumber of datetime that are not transformed\033[0m: \n{df.date.isna().value_counts()}')
print('\033[34m\nThe head of the dataset\033[0m:\n')
df.head()
# Out:
#          Basic statistics
#
# Shape: (44898, 5)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44898 entries, 0 to 44897
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    44898 non-null  object
#  1   text     44898 non-null  object
#  2   subject  44898 non-null  object
#  3   date     11868 non-null  datetime64[ns]
#  4   label    44898 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 1.7+ MB
# None
#
# Descriptive statistics:
#                                                      title   text       subject
# count                                               44898  44898         44898
# unique                                              38729  38646             8
# top     Factbox: Trump fills top jobs for his administ...         politicsNews
# freq                                                   14    627         11272
#
# ...

# %%
df['word_count'] = df['text'].str.split().str.len()
mean_len = df['word_count'].mean()
std_len = df['word_count'].std()
max_seq_len = int(mean_len + 2 * std_len)

print('\033[34mAverage length of words\033[0m: ',mean_len)
print("\033[34mDistribution\033[0m: ", std_len)
print('\033[34mMaximal length text\033[0m: ', max_seq_len)
print('\033[34mDescriptive stats of counts\033[0m: \n',df['word_count'].describe())
# Out:
# Average length of words:  405.28228428883244
# Distribution:  351.26559488348715
# Maximal length text:  1107
# Descriptive stats of counts:
#  count    44898.000000
# mean       405.282284
# std        351.265595
# min          0.000000
# 25%        203.000000
# 50%        362.000000
# 75%        513.000000
# max       8135.000000
# Name: word_count, dtype: float64

# %%
print('\033[34mNumber of duplicates\033[0m: \n', df.duplicated().value_counts())
print('\033[34mNumber of missed values\033[0m: specifics of date transformation \n', df.isna().value_counts())
# Out:
# Number of duplicates:
#  False    44685
# True       213
# Name: count, dtype: int64
# Number of missed values: specifics of date transformation
#  title  text   subject  date   label  word_count
# False  False  False    True   False  False         33030
#                        False  False  False         11868
# Name: count, dtype: int64

# %% [markdown]
# ### Modeling

# %% [markdown]
# #### Model set

# %%
#for models
X_y=df[['text','label']].copy()

# %%
X_y['text'][1]
# Out:
# 'House Intelligence Committee Chairman Devin Nunes is going to have a bad day. He s been under the assumption, like many of us, that the Christopher Steele-dossier was what prompted the Russia investigation so he s been lashing out at the Department of Justice and the FBI in order to protect Trump. As it happens, the dossier is not what started the investigation, according to documents obtained by the New York Times.Former Trump campaign adviser George Papadopoulos was drunk in a wine bar when he revealed knowledge of Russian opposition research on Hillary Clinton.On top of that, Papadopoulos wasn t just a covfefe boy for Trump, as his administration has alleged. He had a much larger role, but none so damning as being a drunken fool in a wine bar. Coffee boys  don t help to arrange a New York meeting between Trump and President Abdel Fattah el-Sisi of Egypt two months before the election. It was known before that the former aide set up meetings with world leaders for Trump, but team 
# ...

# %% [markdown]
# #### Tokenization, encode, padding / truncation, set split

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r"[^a-z0-9\s]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

X_y.loc[:,"text"] = X_y["text"].apply(clean_text)
tokenizer = get_tokenizer('basic_english')

def yield_tokens(data):
    for text in data:
        yield tokenizer(text)
vocab = build_vocab_from_iterator(yield_tokens(X_y['text']), specials=['<pad>','<unk>'])
vocab.set_default_index(vocab['<unk>'])

# max_len = int(mean_len +(2*std_len))
max_len = int(mean_len+10)

def encode(text):
    ids = vocab(tokenizer(text))
    return torch.tensor(ids[:max_len])
encoded = [encode(t) for t in X_y['text']]

X=pad_sequence(encoded, batch_first=True, padding_value=vocab['<pad>'])
y=torch.tensor(df['label'].values)

class Text(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y
    def __len__(self):
        return len(self.y)
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

Xtr, Xtemp, ytr, ytemp = train_test_split(X, y, train_size=0.8, stratify=y, random_state=42)

# 10% val, 10% test
Xval, Xte, yval, yte = train_test_split(Xtemp, ytemp, train_size=0.5, stratify=ytemp, random_state=42)

tr_ds = Text(Xtr, ytr)
val_ds = Text(Xval, yval)
te_ds = Text(Xte, yte)

tr_loader = DataLoader(tr_ds, batch_size=64, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=64)
te_loader = DataLoader(te_ds, batch_size=64)

# %% [markdown]
# #### RNN, LSTM, BILSTM, CNN with with adaptive max pooling

# %%
device = torch.device('cuda')

class RNN(nn.Module):
    def __init__(self, vocab_size, emb=128, hid=128, n_classes=2, dropout=0.5):
        super().__init__()
        self.emb = nn.Embedding(vocab_size, emb, padding_idx=0)
        self.rnn = nn.RNN(emb, hid, batch_first=True)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hid, n_classes)
    def forward(self, x):
        x= self.emb(x)
        _, h = self.rnn(x)
        h = self.dropout(h[-1])
        out=self.fc(h)
        return out
class LSTM(nn.Module):
    def __init__(self, vocab_size, emb=128, hid=256, n_classes=2, dropout=0.5):
        super().__init__()
        self.emb = nn.Embedding(vocab_size, emb, padding_idx=0)
        self.lstm = nn.LSTM(emb, hid, batch_first=True, dropout=0.5, num_layers=2)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hid, n_classes)
    def forward(self, x):
        x = self.emb(x)
        out, _ = self.lstm(x)
        out = out[:, -1, :]
        out = self.dropout(out)
        out = self.fc(out)
        return out
class BILSTM(nn.Module):
    def __init__(self, vocab_size, emb=128, hid=128, n_classes=2, dropout=0.5):
        super().__init__()
        self.emb = nn.Embedding(vocab_size,  emb, padding_idx=0)
        self.lstm = nn.LSTM(emb, hid, batch_first=True, bidirectional=True, dropout=0.5, num_layers=2)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hid*2, n_classes)
    def forward(self, x):
        x = self.emb(x)
        out, _ = self.lstm(x)
        out = out[:, -1, :]
        out = self.dropout(out)
        out = self.fc(out)
        return out
class CNN(nn.Module):
    def __init__(self, vocab_size, emb=128, n_classes=2, dropout=0.5):
        super().__init__()
        self.emb = nn.Embedding(vocab_size, emb, padding_idx=0)
        self.conv = nn.Conv1d(emb, 256, kernel_size=5)
        self.pool = nn.AdaptiveMaxPool1d(1)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(256, n_classes)
    def forward(self, x):
        x = self.emb(x).transpose(1,2)
        x = torch.relu(self.conv(x))
        x = self.pool(x).squeeze(-1)
        x = self.dropout(x)
        out = self.fc(x)
        return out

# %% [markdown]
# #### Training, testing

# %%
def train_epoch(model, loader, optimizer, criterion):
    model.train()
    total_loss, correct, total = 0,0,0

    for x, y in loader:
        x,y = x.to(device), y.to(device)
        optimizer.zero_grad()
        out = model(x)
        loss = criterion(out, y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        correct += (out.argmax(1)==y).sum().item()
        total+=y.size(0)
    return total_loss / total, correct/total
def eval_epoch(model, loader, criterion):
    model.eval()
    total_loss, correct, total= 0.0,0,0
    preds, labels = [],[]
    with torch.no_grad():
        for x,y in loader:
            x,y = x.to(device), y.to(device)
            out = model(x)
            loss=criterion(out,y)
            total_loss += loss.item()
            correct += (out.argmax(1)==y).sum().item()
            total += y.size(0)
            preds.extend(out.argmax(1).cpu().numpy())
            labels.extend(y.cpu().numpy())
    return total_loss/total, correct/total, labels, preds
def train_model(model, epochs=10):
    model.to(device)
    opt = torch.optim.Adam(model.parameters(), lr=10**-3, weight_decay=10**-4)
    crit = nn.CrossEntropyLoss()

    trl, tra, tel, tea = [], [], [], []

    for epoch in range(epochs):
        l, a = train_epoch(model, tr_loader, opt, crit)
        vl, va, labels, preds = eval_epoch(model, te_loader, crit)

        trl.append(l) 
        tra.append(a)
        tel.append(vl) 
        tea.append(va)
        print(f"Epoch {epoch+1:02d} | "
              f"Train Loss: {l:.4f}, Acc: {a:.4f} | "
              f"Val Loss: {vl:.4f}, Acc: {va:.4f}")

    return trl, tra, tel, tea

# %%
models = {
    'RNN':RNN(vocab_size=len(vocab)),
    'LSTM':LSTM(vocab_size=len(vocab)),
    'BILSTM':BILSTM(vocab_size=len(vocab)),
    'CNN':CNN(vocab_size=len(vocab))
}

results = {}

for name, model in models.items():
    print(f"Training {name}...")
    trl, tra, tel, tea = train_model(model, epochs=10)
    test_loss, test_acc, labels, preds = eval_epoch(
        model, te_loader, nn.CrossEntropyLoss()
    )
    results[name] = {
        "model": model,
        "train_losses": trl,
        "train_accs": tra,
        "test_losses": tel,
        "test_accs": tea,
        "labels": labels,
        "preds": preds
    }
# Out:
# Training RNN...
# Epoch 01 | Train Loss: 0.0108, Acc: 0.5187 | Val Loss: 0.0109, Acc: 0.5385
# Epoch 02 | Train Loss: 0.0107, Acc: 0.5418 | Val Loss: 0.0102, Acc: 0.5920
# Epoch 03 | Train Loss: 0.0095, Acc: 0.6308 | Val Loss: 0.0135, Acc: 0.5993
# Epoch 04 | Train Loss: 0.0063, Acc: 0.8413 | Val Loss: 0.0048, Acc: 0.9058
# Epoch 05 | Train Loss: 0.0093, Acc: 0.6351 | Val Loss: 0.0109, Acc: 0.5606
# Epoch 06 | Train Loss: 0.0107, Acc: 0.5652 | Val Loss: 0.0113, Acc: 0.5214
# Epoch 07 | Train Loss: 0.0108, Acc: 0.5589 | Val Loss: 0.0098, Acc: 0.6864
# Epoch 08 | Train Loss: 0.0078, Acc: 0.7739 | Val Loss: 0.0069, Acc: 0.8401
# Epoch 09 | Train Loss: 0.0068, Acc: 0.8461 | Val Loss: 0.0068, Acc: 0.8448
# Epoch 10 | Train Loss: 0.0067, Acc: 0.8477 | Val Loss: 0.0068, Acc: 0.8454
# Training LSTM...
# Epoch 01 | Train Loss: 0.0105, Acc: 0.5753 | Val Loss: 0.0110, Acc: 0.5192
# Epoch 02 | Train Loss: 0.0108, Acc: 0.5111 | Val Loss: 0.0109, Acc: 0.5245
# ...

# %%
def visualize_model(name, res):
    model = res["model"]
    trl, tra, tel, tea = res["train_losses"], res["train_accs"], res["test_losses"], res["test_accs"]
    labels, preds = res["labels"], res["preds"]

    fig, axes = plt.subplots(3, 2, figsize=(16,18))
    axes = axes.flatten()
    
    # Loss
    axes[0].plot(trl, label="Train Loss", linewidth=2)
    axes[0].plot(tel, label="Test Loss", linewidth=2)
    axes[0].set_title(f"{name} Loss Curves")
    axes[0].set_xlabel("Epochs")
    axes[0].set_ylabel("Loss")
    axes[0].legend()

    # Accuracy
    axes[1].plot(tra, label="Train Accuracy", linewidth=2)
    axes[1].plot(tea, label="Test Accuracy", linewidth=2)
    axes[1].set_title(f"{name} Accuracy Curves")
    axes[1].set_xlabel("Epochs")
    axes[1].set_ylabel("Accuracy")
    axes[1].legend()

    # Confusion Matrix
    cm = confusion_matrix(labels, preds)
    sns.heatmap(cm, annot=True, fmt="d", cmap="YlGnBu", ax=axes[2])
    axes[2].set_title(f"{name} Confusion Matrix")
    axes[2].set_xlabel("Predicted")
    axes[2].set_ylabel("True")

    # Normalized CM
    sns.heatmap(cm/cm.sum(axis=1, keepdims=True), annot=True, fmt=".2f", cmap="YlOrBr", ax=axes[3])
    axes[3].set_title(f"{name} Normalized Confusion Matrix")
    axes[3].set_xlabel("Predicted")
    axes[3].set_ylabel("True")

    # Confidence distribution
    probs=[]
    model.eval()
    with torch.no_grad():
        for x,_ in te_loader:
            x = x.to(device)
            out = model(x)
            p = torch.softmax(out, dim=1).max(dim=1)[0]
            probs.extend(p.cpu().numpy())
    sns.histplot(probs, bins=20, kde=True, ax=axes[4])
    axes[4].set_title(f"{name} Confidence Distribution")
    axes[4].set_xlabel("Max Softmax Probability")
    axes[4].set_ylabel("Count")

    plt.tight_layout()
    plt.show()

    print(f"\n{name} Classification Report")
    print(classification_report(labels, preds, target_names=["Fake","Real"]))


    example = torch.randint(0, len(vocab), (1, max_len)).to(device)
    traced = torch.jit.trace(model, example)
    traced.save(f"{name.lower()}_text_model_netron.pt")
    print(f"{name} model saved for Netron")

for name, res in results.items():
    visualize_model(name, res)
# Out:
# RNN Classification Report
#               precision    recall  f1-score   support
#
#         Fake       0.84      0.87      0.85      2348
#         Real       0.85      0.82      0.84      2142
#
#     accuracy                           0.85      4490
#    macro avg       0.85      0.84      0.84      4490
# weighted avg       0.85      0.85      0.85      4490
#
# RNN model saved for Netron
# LSTM Classification Report
#               precision    recall  f1-score   support
#
#         Fake       0.97      1.00      0.98      2348
#         Real       1.00      0.96      0.98      2142
#
#     accuracy                           0.98      4490
#    macro avg       0.98      0.98      0.98      4490
# weighted avg       0.98      0.98      0.98      4490
#
# LSTM model saved for Netron
# BILSTM Classification Report
#               precision    recall  f1-score   support
#
#         Fake       0.98      1.00      0.99      2348
# ...
